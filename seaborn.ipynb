# %% [markdown]
# # Types of plots in Seaborn.
#
# 1. Relational plots
# 2. Categorical plots
# 3. Distribution plots
# 4. Regression plots

# %% [markdown]
# 1. Relational plots
#
# line plot
# scatter plot

# %%
import seaborn as sns

# display flights dataset as data frame. 
data = sns.load_dataset("flights")
data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %% [markdown]
# Some datasets in seaborn
# tips, iris, titanic, flights, diamonds, exercise and planets

# %%
# display specific data.

passengers_feb = data[data["month"]=="Feb" ]
passengers_feb
# Out:
#      year month  passengers
# 1    1949   Feb         118
# 13   1950   Feb         126
# 25   1951   Feb         150
# 37   1952   Feb         180
# 49   1953   Feb         196
# 61   1954   Feb         188
# 73   1955   Feb         233
# 85   1956   Feb         277
# 97   1957   Feb         301
# 109  1958   Feb         318
# 121  1959   Feb         342
# 133  1960   Feb         391

# %%
# draw line chart 
import matplotlib.pyplot as plt
sns.set_style("darkgrid")
sns.lineplot(x="year", y="passengers", data=passengers_feb)
plt.title("Chart between Year and Passengers")
plt.ylabel("Passengers")
# Out:
# Text(0, 0.5, 'Passengers')

# %%
sns.lineplot(x="year", y="passengers", data=data, size="month" , hue="month")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
diamonds = sns.load_dataset("diamonds")
diamonds

expensive_diamonds =diamonds[diamonds["price"]>18000]
expensive_diamonds


# plt.figure(figsize=(10,10))
sns.lineplot(x="cut", y="price", data=diamonds)
# Out:
# <Axes: xlabel='cut', ylabel='price'>

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fmri, x="timepoint", y="signal",hue="event", kind='line', style='region' , col='region', row="event")

# %%
a = fmri[(fmri["event"]=="stim") & (fmri["region"] == "parietal")]
a
plt.title("relation between signal and time point when region = parietal event = stim ")
sns.lineplot(x="timepoint", y="signal", data=a)
# Out:
# <Axes: title={'center': 'relation between signal and time point when regin = parietal event = stim '}, xlabel='timepoint', ylabel='signal'>

# %% [markdown]
# # Regression plots

# %%
import seaborn as sns
sns.set_style("dark")
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64
