# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Some datasets in seaborn
# tips, iris, titanic, flights, diamonds, exercise and planets

# %% [markdown]
# # load data from seaborn

# %%
# load dataset about flights
data = sns.load_dataset("flights")
data
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
new_data = data[data["year"] ==1950]
new_data
# Out:
#     year month  passengers
# 12  1950   Jan         115
# 13  1950   Feb         126
# 14  1950   Mar         141
# 15  1950   Apr         135
# 16  1950   May         125
# 17  1950   Jun         149
# 18  1950   Jul         170
# 19  1950   Aug         170
# 20  1950   Sep         158
# 21  1950   Oct         133
# 22  1950   Nov         114
# 23  1950   Dec         140

# %%
# change size of figure 
sns.set_style("dark")
plt.figure(figsize=(10,10))
plt.title("Line between passengers and year")

# draw line plot using seaborn 
sns.lineplot(x="year", y="passengers", data=data, size="month", hue="month")
plt.ylabel("Passengers")

# change interval of axis.
plt.locator_params(axis='y', nbins=80) 
plt.locator_params(axis='x', nbins=10)
